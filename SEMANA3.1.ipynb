# %% [markdown]
# <a href="https://colab.research.google.com/github/geral108/SEMANA3/blob/main/SEMANA3.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TAREA:DEFINIR CUANTOS ESTUDIANTES SON (SACAR DOS GRAFICOS CON EL EJERCICIO ANTERIOR TOMANDO EN CUENTA LA MEDIA Y LA DESVIACION ESTANDAR PERO DE SUS PESOS) , DE LA CANTIDAD DE ESTUDIANTES EL PORCENTAJE DE VARONES Y MUJERES(Y OTRO GRAFICO ); AMBOS EN DIAGRAMA DE PASTELES

# %%
import numpy as np
import matplotlib.pyplot as plt
peso1 = int(input("Ingrese el peso del primer estudiante: "))
peso2 = int(input("Ingrese el peso del segundo estudiante: "))
peso3 = int(input("Ingrese el peso del tercer estudiante: "))
peso4 = int(input("Ingrese el peso del cuarto estudiante: "))
peso5 = int(input("Ingrese el peso del quinto estudiante: "))

peso = np.array([peso1, peso2, peso3,peso4,peso5])
media = np.mean(peso)
desviacion_peso = np.std(peso)
print("La media de las edades es: ", media)
print("El promedio de las edades es: ", desviacion_peso ,'\n')

fig, ax = plt.subplots()
ax.pie([media, desviacion_peso], labels=['Media', 'Desviacion Estandar'])
plt.show()
# Out:
# Ingrese el peso del primer estudiante: 52
# Ingrese el peso del segundo estudiante: 56
# Ingrese el peso del tercer estudiante: 57
# Ingrese el peso del cuarto estudiante: 54
# Ingrese el peso del quinto estudiante: 52
# La media de las edades es:  54.2
# El promedio de las edades es:  2.0396078054371136

# %%
import numpy as np
import matplotlib.pyplot as plt
varon = int(input("Ingrese la cantidad de estudiantes varones: "))
mujer = int(input("Ingrese la cantidad de estudiantes mujeres: "))

fig, ax = plt.subplots(figsize=(6, 6))
ax.pie([varon,mujer], labels=['Varones', 'Mujeres'],autopct='%1.1f%%')
plt.show()
# Out:
# Ingrese la cantidad de estudiantes varones: 12
# Ingrese la cantidad de estudiantes mujeres: 4

# %% [markdown]
# DIAGRAMA DE CAJAS Y BIGOTES

# %%
import matplotlib.pyplot as plt #IMPORTAS
fig, ax = plt.subplots() # EL SUBPLOTEO
ax.boxplot([1, 2, 1, 2, 3, 4, 3, 3, 5, 7]) # AFECTAN A LA LISTA X(GENERANDO UN PUNTO 1 , PUNTO 2; LUEGO SUBE LUEGO PUNTO 1 PNTO 2)
plt.show() #IMPRIMIRLO

# %% [markdown]
# DIAGRAMAS DE VIOLIN

# %%
#OJO TODO LOS AFECTOS ON PARa le eje x en todos
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.violinplot([1, 2, 1, 2, 3, 4, 3, 3, 5, 7])
plt.show()

# %% [markdown]
# DIAGARAMA DE CONTORNOS

# %%
#TRABAJA CON EL JEE X, Y, Z
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x = np.linspace(-3.0, 3.0, 100) #GENERAMOS SU ENTORNO (LINSPACE-> ES UN ESPCAIO)
y = np.linspace(-3.0, 3.0, 100)
x, y = np.meshgrid(x, y) #GENERA UN DATO ESPECIFICO
z = np.sqrt(x**2 + 2*y**2)
ax.contourf(x, y, z)
plt.show()

# %% [markdown]
# MAPAS DE COLOR

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
x = np.random.random((18, 18)) # SON LOS NUMEROS DE CUADRITOS QUE HAY
ax.imshow(x) #Dibuja un mapa de color a partir de una matriz
plt.show()

# %% [markdown]
# DIAGRAMA DE LINEAS

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot([1, 1, 3, 4], [1, 2, 0, 0.5])
plt.show()

# %% [markdown]
# Colores

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
dias = ['L', 'M', 'X', 'J', 'V', 'S', 'D'] #DIAS DE LA SEMANA
temperaturas = {'Madrid':[28.5, 30.5, 31, 30, 28, 27.5, 30.5], 'Barcelona':[24.5, 25.5, 26.5, 25, 26.5, 24.5, 25]} #TEMPERATURAS
ax.plot(dias, temperaturas['Madrid'], color = 'tab:purple') #DIAS Y LA TEMPERATURA; Y SE LE AGREGA EL COLOR
ax.plot(dias, temperaturas['Barcelona'], color = 'tab:green')
plt.show()

# %% [markdown]
# MARCADORES

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
dias = ['L', 'M', 'X', 'J', 'V', 'S', 'D']
temperaturas = {'Madrid':[28.5, 30.5, 31, 30, 28, 27.5, 30.5], 'Barcelona':[24.5, 25.5, 26.5, 25, 26.5, 24.5, 25]}
ax.plot(dias, temperaturas['Madrid'], marker = '^')
ax.plot(dias, temperaturas['Barcelona'], marker = 'o')
plt.show()

# %% [markdown]
# LÍNEA

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
dias = ['L', 'M', 'X', 'J', 'V', 'S', 'D']
temperaturas = {'Madrid':[28.5, 30.5, 31, 30, 28, 27.5, 30.5], 'Barcelona':[24.5, 25.5, 26.5, 25, 26.5, 24.5, 25]}
ax.plot(dias, temperaturas['Madrid'], linestyle = 'dashed') # GENREAN LIENAS CONTINUAS
ax.plot(dias, temperaturas['Barcelona'], linestyle = 'dotted') # GENERAN PUNTOS
plt.show()

# %% [markdown]
# TITULOS

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
dias = ['L', 'M', 'X', 'J', 'V', 'S', 'D']
temperaturas = {'Madrid':[28.5, 30.5, 31, 30, 28, 27.5, 30.5], 'Barcelona':[24.5, 25.5, 26.5, 25, 26.5, 24.5, 25]}
ax.plot(dias, temperaturas['Madrid'])
ax.plot(dias, temperaturas['Barcelona'])
ax.set_title('Evolución de la temperatura diaria', loc = "left", fontdict = {'fontsize':14, 'fontweight':'bold', 'color':'tab:blue'}) #TITULO
plt.show()

# %% [markdown]
# EJES

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
dias = ['L', 'M', 'X', 'J', 'V', 'S', 'D']
temperaturas = {'Madrid':[28.5, 30.5, 31, 30, 28, 27.5, 30.5], 'Barcelona':[24.5, 25.5, 26.5, 25, 26.5, 24.5, 25]}
ax.plot(dias, temperaturas['Madrid'])
ax.plot(dias, temperaturas['Barcelona'])
ax.set_xlabel("Días", fontdict = {'fontsize':14, 'fontweight':'bold', 'color':'tab:blue'})
ax.set_ylabel("Temperatura ºC")
ax.set_ylim([20,35])
ax.set_yticks(range(20, 35))
plt.show()

# %% [markdown]
# LEYENDA

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
dias = ['L', 'M', 'X', 'J', 'V', 'S', 'D']
temperaturas = {'Madrid':[28.5, 30.5, 31, 30, 28, 27.5, 30.5], 'Barcelona':[24.5, 25.5, 26.5, 25, 26.5, 24.5, 25]}
ax.plot(dias, temperaturas['Madrid'], label = 'Madrid')
ax.plot(dias, temperaturas['Barcelona'], label = 'Barcelona')
ax.legend(loc = 'upper right')
plt.show()

# %% [markdown]
# REJILLA

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
dias = ['L', 'M', 'X', 'J', 'V', 'S', 'D']
temperaturas = {'Madrid':[28.5, 30.5, 31, 30, 28, 27.5, 30.5], 'Barcelona':[24.5, 25.5, 26.5, 25, 26.5, 24.5, 25]}
ax.plot(dias, temperaturas['Madrid'])
ax.plot(dias, temperaturas['Barcelona'])
ax.grid(axis = 'y', color = 'gray', linestyle = 'dashed')
plt.show()

# %% [markdown]
# MULTIPLES GRAFICOS

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(2, 2, sharey = True)
dias = ['L', 'M', 'X', 'J', 'V', 'S', 'D']
temperaturas = {'Madrid':[28.5, 30.5, 31, 30, 28, 27.5, 30.5], 'Barcelona':[24.5, 25.5, 26.5, 25, 26.5, 24.5, 25]}
ax[0, 0].plot(dias, temperaturas['Madrid'])
ax[0, 1].plot(dias, temperaturas['Barcelona'], color = 'tab:orange')
ax[1, 0].bar(dias, temperaturas['Madrid'])
ax[1, 1].bar(dias, temperaturas['Barcelona'], color = 'tab:orange')
plt.show()

# %% [markdown]
# INTEGRACION CON PANDA - CUANDO SE TRABAJA CON EXCEL

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.DataFrame({'Días':['L', 'M', 'X', 'J', 'V', 'S', 'D'],
                   'Madrid':[28.5, 30.5, 31, 30, 28, 27.5, 30.5],
                   'Barcelona':[24.5, 25.5, 26.5, 25, 26.5, 24.5, 25]})
fig, ax = plt.subplots()
df.plot(x = 'Días', y = 'Madrid', ax = ax)
df.plot(x = 'Días', y = 'Barcelona', ax = ax)
plt.show()
